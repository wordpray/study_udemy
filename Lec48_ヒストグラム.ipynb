# %%
import numpy as np
from numpy.random import randn
import pandas as pd

# %%
from scipy import stats

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1= randn(100)

# %%
dataset1
# Out:
# array([-0.48602912,  2.65867883,  0.81757043,  0.45409484, -2.53729433,
#         2.49956529, -0.41832066, -0.66309817, -1.31223605, -0.06223345,
#        -1.36724576,  0.89278606,  0.74022124,  0.78090237, -0.60951976,
#        -0.51061585,  0.17383379, -0.62156034, -0.9749063 , -0.32683022,
#         1.35591998,  0.87301943, -1.18650988, -0.44138009,  1.12991476,
#         2.40273848, -0.03486008, -1.13481569, -0.09010524, -0.4515613 ,
#         0.07375837,  1.72044638,  0.83211012,  0.17401741, -0.1101665 ,
#        -0.58091594, -1.72098563, -0.36834843, -0.50215088, -0.50616363,
#        -1.42841697, -0.03889953,  0.76470417,  0.15207105,  0.96853675,
#        -0.57468319, -0.02411402,  1.26628753, -2.32393041,  1.01063095,
#        -0.50430667,  0.87490176,  1.88661688,  0.76836798,  0.03655513,
#         1.49738101, -1.30836667,  0.50092291,  0.18460428, -0.71749155,
#        -1.12107413, -0.08489047, -0.72685689,  1.35677137,  1.15772118,
#        -0.69583034, -0.92357193,  0.43216433,  0.28426973,  1.54226409,
#        -1.9934285 ,  1.29345147,  0.46738016, -0.16349026,  1.73268991,
#        -1.30224837,  1.38532668,  0.94049247,  0.85781545,  0.47086904,
#        -0.57507441,  0.21397306,  0.45584384, -1.02031952, -0.61336973,
#         0.74176068,  0.58804419, -0.70579226,  1.55252099,  0.27245307,
#         0.43913353, -0.58315144,  0.16982336,  0.30037947, -1.4664208 ,
#         0.18387391,  2.03210866,  0.17159705, -0.44980676, -0.18169407])

# %%
plt.hist(dataset1)
# Out:
# (array([  2.,   2.,  10.,  19.,  16.,  19.,  15.,  10.,   4.,   3.]),
#  array([-2.53729433, -2.01769701, -1.4980997 , -0.97850238, -0.45890507,
#          0.06069225,  0.58028956,  1.09988688,  1.6194842 ,  2.13908151,
#          2.65867883]),
#  <a list of 10 Patch objects>)

# %%
dataset2= randn(80)
plt.hist(dataset2, color = 'indianred')
# Out:
# (array([  4.,   4.,  10.,  15.,  20.,  16.,   4.,   4.,   1.,   2.]),
#  array([-2.5920345 , -2.00159122, -1.41114795, -0.82070467, -0.23026139,
#          0.36018189,  0.95062516,  1.54106844,  2.13151172,  2.72195499,
#          3.31239827]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed= True)
# Out:
# (array([ 0.03849135,  0.03849135,  0.19245673,  0.36566779,  0.30793077,
#          0.36566779,  0.28868509,  0.19245673,  0.07698269,  0.05773702]),
#  array([-2.53729433, -2.01769701, -1.4980997 , -0.97850238, -0.45890507,
#          0.06069225,  0.58028956,  1.09988688,  1.6194842 ,  2.13908151,
#          2.65867883]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(dataset1, normed= True, alpha= 0.5, bins= 20)
plt.hist(dataset2, normed= True, alpha= 0.5, bins= 20, color= 'indianred')
# Out:
# (array([ 0.08468214,  0.08468214,  0.08468214,  0.08468214,  0.16936428,
#          0.25404642,  0.33872856,  0.29638749,  0.33872856,  0.50809284,
#          0.21170535,  0.46575177,  0.08468214,  0.08468214,  0.12702321,
#          0.04234107,  0.04234107,  0.        ,  0.04234107,  0.04234107]),
#  array([-2.5920345 , -2.29681286, -2.00159122, -1.70636958, -1.41114795,
#         -1.11592631, -0.82070467, -0.52548303, -0.23026139,  0.06496025,
#          0.36018189,  0.65540352,  0.95062516,  1.2458468 ,  1.54106844,
#          1.83629008,  2.13151172,  2.42673335,  2.72195499,  3.01717663,
#          3.31239827]),
#  <a list of 20 Patch objects>)

# %%
data1= randn(1000)

# %%
data2= randn(1000)

# %%
sns.jointplot(data1, data2)

# %%
sns.jointplot(data1, data2, kind= 'hex')
